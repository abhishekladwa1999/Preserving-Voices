# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
lang_data = 'Languages.zip'
df_lang = pd.read_csv(lang_data)

# %%
df_lang
# Out:
#     Unnamed: 0                                           Language  \
# 0            0                    English(excl. creole languages)
# 1            1  Mandarin Chinese(incl. Standard Chinese, but e...
# 2            2                                  Hindi(excl. Urdu)
# 3            3                                            Spanish
# 4            4                                             French
# 5            5             Modern Standard Arabic(excl. dialects)
# 6            6                                            Bengali
# 7            7                                            Russian
# 8            8                                         Portuguese
# 9            9                                  Urdu(excl. Hindi)
# 10          10                            Indonesian(excl. Malay)
# 11          11                                    Standard German
# 12          12                                           Japanese
# ...

# %%
df_lang.shape
# Out:
# (45, 7)

# %%
df_lang.drop(columns = ['Family' ,	'Branch',	'First-language(L1) speakers',	'Second-language(L2) speakers'], axis = 1, inplace = True)

# %%
df_lang
# Out:
#     Unnamed: 0                                           Language  \
# 0            0                    English(excl. creole languages)
# 1            1  Mandarin Chinese(incl. Standard Chinese, but e...
# 2            2                                  Hindi(excl. Urdu)
# 3            3                                            Spanish
# 4            4                                             French
# 5            5             Modern Standard Arabic(excl. dialects)
# 6            6                                            Bengali
# 7            7                                            Russian
# 8            8                                         Portuguese
# 9            9                                  Urdu(excl. Hindi)
# 10          10                            Indonesian(excl. Malay)
# 11          11                                    Standard German
# 12          12                                           Japanese
# ...

# %%
df_lang['Degree of endangerment'] = 'Safe'

# %%
df_lang
# Out:
#     Unnamed: 0                                           Language  \
# 0            0                    English(excl. creole languages)
# 1            1  Mandarin Chinese(incl. Standard Chinese, but e...
# 2            2                                  Hindi(excl. Urdu)
# 3            3                                            Spanish
# 4            4                                             French
# 5            5             Modern Standard Arabic(excl. dialects)
# 6            6                                            Bengali
# 7            7                                            Russian
# 8            8                                         Portuguese
# 9            9                                  Urdu(excl. Hindi)
# 10          10                            Indonesian(excl. Malay)
# 11          11                                    Standard German
# 12          12                                           Japanese
# ...

# %%
df_lang['Countries'] = '*Country*'

# %%
df_lang
# Out:
#     Unnamed: 0                                           Language  \
# 0            0                    English(excl. creole languages)
# 1            1  Mandarin Chinese(incl. Standard Chinese, but e...
# 2            2                                  Hindi(excl. Urdu)
# 3            3                                            Spanish
# 4            4                                             French
# 5            5             Modern Standard Arabic(excl. dialects)
# 6            6                                            Bengali
# 7            7                                            Russian
# 8            8                                         Portuguese
# 9            9                                  Urdu(excl. Hindi)
# 10          10                            Indonesian(excl. Malay)
# 11          11                                    Standard German
# 12          12                                           Japanese
# ...

# %%
df_lang['GDP Per Capita'] = '*GDP Per Capita*'

# %%
df_lang
# Out:
#     Unnamed: 0                                           Language  \
# 0            0                    English(excl. creole languages)
# 1            1  Mandarin Chinese(incl. Standard Chinese, but e...
# 2            2                                  Hindi(excl. Urdu)
# 3            3                                            Spanish
# 4            4                                             French
# 5            5             Modern Standard Arabic(excl. dialects)
# 6            6                                            Bengali
# 7            7                                            Russian
# 8            8                                         Portuguese
# 9            9                                  Urdu(excl. Hindi)
# 10          10                            Indonesian(excl. Malay)
# 11          11                                    Standard German
# 12          12                                           Japanese
# ...

# %%
df_lang['Most likely cause of death'] = '*Most likely cause of death*'

# %%
df_lang
# Out:
#     Unnamed: 0                                           Language  \
# 0            0                    English(excl. creole languages)
# 1            1  Mandarin Chinese(incl. Standard Chinese, but e...
# 2            2                                  Hindi(excl. Urdu)
# 3            3                                            Spanish
# 4            4                                             French
# 5            5             Modern Standard Arabic(excl. dialects)
# 6            6                                            Bengali
# 7            7                                            Russian
# 8            8                                         Portuguese
# 9            9                                  Urdu(excl. Hindi)
# 10          10                            Indonesian(excl. Malay)
# 11          11                                    Standard German
# 12          12                                           Japanese
# ...

# %%
df_lang.drop(columns = ['Unnamed: 0'], axis = 1, inplace = True)

# %%
df_lang
# Out:
#                                              Language Total speakers(L1+L2)  \
# 0                     English(excl. creole languages)         1.452 billion
# 1   Mandarin Chinese(incl. Standard Chinese, but e...         1.118 billion
# 2                                   Hindi(excl. Urdu)         602.2 million
# 3                                             Spanish         548.3 million
# 4                                              French         274.1 million
# 5              Modern Standard Arabic(excl. dialects)         274.0 million
# 6                                             Bengali         272.7 million
# 7                                             Russian         258.2 million
# 8                                          Portuguese         257.7 million
# 9                                   Urdu(excl. Hindi)         231.3 million
# 10                            Indonesian(excl. Malay)         199.0 million
# ...

# %%
df_lang.rename(columns={"Total speakers(L1+L2)": "Number of speakers"}, inplace=True)

# %%
df_lang
# Out:
#                                              Language Number of speakers  \
# 0                     English(excl. creole languages)      1.452 billion
# 1   Mandarin Chinese(incl. Standard Chinese, but e...      1.118 billion
# 2                                   Hindi(excl. Urdu)      602.2 million
# 3                                             Spanish      548.3 million
# 4                                              French      274.1 million
# 5              Modern Standard Arabic(excl. dialects)      274.0 million
# 6                                             Bengali      272.7 million
# 7                                             Russian      258.2 million
# 8                                          Portuguese      257.7 million
# 9                                   Urdu(excl. Hindi)      231.3 million
# 10                            Indonesian(excl. Malay)      199.0 million
# 11                                    Standard German      134.6 million
# ...

# %%
df_lang['Number of speakers'] = df_lang['Number of speakers'].str.replace('million', '')

# %%
df_lang
# Out:
#                                              Language Number of speakers  \
# 0                     English(excl. creole languages)      1.452 billion
# 1   Mandarin Chinese(incl. Standard Chinese, but e...      1.118 billion
# 2                                   Hindi(excl. Urdu)             602.2
# 3                                             Spanish             548.3
# 4                                              French             274.1
# 5              Modern Standard Arabic(excl. dialects)             274.0
# 6                                             Bengali             272.7
# 7                                             Russian             258.2
# 8                                          Portuguese             257.7
# 9                                   Urdu(excl. Hindi)             231.3
# 10                            Indonesian(excl. Malay)             199.0
# 11                                    Standard German             134.6
# ...

# %%
df_lang['Number of speakers'] = df_lang['Number of speakers'].str.replace('billion', '')

# %%
df_lang
# Out:
#                                              Language Number of speakers  \
# 0                     English(excl. creole languages)             1.452
# 1   Mandarin Chinese(incl. Standard Chinese, but e...             1.118
# 2                                   Hindi(excl. Urdu)             602.2
# 3                                             Spanish             548.3
# 4                                              French             274.1
# 5              Modern Standard Arabic(excl. dialects)             274.0
# 6                                             Bengali             272.7
# 7                                             Russian             258.2
# 8                                          Portuguese             257.7
# 9                                   Urdu(excl. Hindi)             231.3
# 10                            Indonesian(excl. Malay)             199.0
# 11                                    Standard German             134.6
# ...

# %%
df_lang['Number of speakers'] = df_lang[['Number of speakers']].astype(float)

# %%
df_lang
# Out:
#                                              Language  Number of speakers  \
# 0                     English(excl. creole languages)               1.452
# 1   Mandarin Chinese(incl. Standard Chinese, but e...               1.118
# 2                                   Hindi(excl. Urdu)             602.200
# 3                                             Spanish             548.300
# 4                                              French             274.100
# 5              Modern Standard Arabic(excl. dialects)             274.000
# 6                                             Bengali             272.700
# 7                                             Russian             258.200
# 8                                          Portuguese             257.700
# 9                                   Urdu(excl. Hindi)             231.300
# 10                            Indonesian(excl. Malay)             199.000
# 11                                    Standard German             134.600
# ...

# %%
df_lang['Language']
# Out:
# 0                       English(excl. creole languages)
# 1     Mandarin Chinese(incl. Standard Chinese, but e...
# 2                                     Hindi(excl. Urdu)
# 3                                               Spanish
# 4                                                French
# 5                Modern Standard Arabic(excl. dialects)
# 6                                               Bengali
# 7                                               Russian
# 8                                            Portuguese
# 9                                     Urdu(excl. Hindi)
# 10                              Indonesian(excl. Malay)
# 11                                      Standard German
# 12                                             Japanese
# 13                                      Nigerian Pidgin
# 14                                              Marathi
# 15                                               Telugu
# 16                                              Turkish
# ...

# %%
df_lang['Countries'] = ['United Kingdom',
'China',
'India',
'Spain',
'France',
'Saudi Arabia, UAE, Kuwait, Qatar, Bahrain, Oman, Iraq, Yemen',
'Bangladesh',
'Russia',
'Portugal',
'Pakistan',
'Indonesia',
'Germany',
'Japan',
'Nigeria',
'India',
'India',
'Turkey',
'India, Sri Lanka',
'China',
'Vietnam',
'Philippines',
'China',
'South Korea',
'Iran',
'Nigeria',
'Egypt',
'Uganda, Kenya, Tanzania',
'Indonesia',
'Italy',
'Pakistan, India',
'India',
'India',
'Thailand',
'Ethiopia',
'India, Nepal',
'India',
'China',
'China',
'Nigeria',
'China',
'Myanmar',
'Sudan',
'Poland',
'Algeria',
'Democratic Republic of Congo']

# %%
df_lang
# Out:
#                                              Language  Number of speakers  \
# 0                     English(excl. creole languages)               1.452
# 1   Mandarin Chinese(incl. Standard Chinese, but e...               1.118
# 2                                   Hindi(excl. Urdu)             602.200
# 3                                             Spanish             548.300
# 4                                              French             274.100
# 5              Modern Standard Arabic(excl. dialects)             274.000
# 6                                             Bengali             272.700
# 7                                             Russian             258.200
# 8                                          Portuguese             257.700
# 9                                   Urdu(excl. Hindi)             231.300
# 10                            Indonesian(excl. Malay)             199.000
# 11                                    Standard German             134.600
# ...

# %%
df_lang['GDP Per Capita'] = [43000, 10000, 2000, 30000, 41000, 24125, 1900, 11000, 24000, 1400,
    4100, 53000, 40000, 2000, 2000, 2000, 9000, 3050, 10000, 2500,
    3500, 10000, 34000, 5000, 2000, 3000, 1233, 4100, 34000, 1700,
    2000, 2000, 7000, 900, 1500, 2000, 10000, 10000, 2000, 10000,
    1400, 4800, 15000, 4000, 500]

# %%
df_lang
# Out:
#                                              Language  Number of speakers  \
# 0                     English(excl. creole languages)               1.452
# 1   Mandarin Chinese(incl. Standard Chinese, but e...               1.118
# 2                                   Hindi(excl. Urdu)             602.200
# 3                                             Spanish             548.300
# 4                                              French             274.100
# 5              Modern Standard Arabic(excl. dialects)             274.000
# 6                                             Bengali             272.700
# 7                                             Russian             258.200
# 8                                          Portuguese             257.700
# 9                                   Urdu(excl. Hindi)             231.300
# 10                            Indonesian(excl. Malay)             199.000
# 11                                    Standard German             134.600
# ...

# %%
df_lang['Average number of years of schooling'] = [12.90, 7.80, 6.40, 9.80, 11.50, 8.40, 5.80, 12.00, 9.20, 5.20, 8.00, 14.10, 12.80, 6.20, 6.40, 6.40, 8.00, 6.65, 7.80, 8.20, 9.30, 7.80, 12.10, 9.80, 6.20, 9.80, 6.45, 8.00, 10.20, 5.80, 6.40, 6.40, 7.60, 2.70, 5.65, 6.40, 7.80, 7.80, 6.20, 7.80, 4.90, 3.70, 11.90, 8.00, 4.30]

# %%
df_lang
# Out:
#                                              Language  Number of speakers  \
# 0                     English(excl. creole languages)               1.452
# 1   Mandarin Chinese(incl. Standard Chinese, but e...               1.118
# 2                                   Hindi(excl. Urdu)             602.200
# 3                                             Spanish             548.300
# 4                                              French             274.100
# 5              Modern Standard Arabic(excl. dialects)             274.000
# 6                                             Bengali             272.700
# 7                                             Russian             258.200
# 8                                          Portuguese             257.700
# 9                                   Urdu(excl. Hindi)             231.300
# 10                            Indonesian(excl. Malay)             199.000
# 11                                    Standard German             134.600
# ...

# %%
df_lang.drop(columns = ['Most likely cause of death'], inplace = True)

# %%
df_lang
# Out:
#                                              Language  Number of speakers  \
# 0                     English(excl. creole languages)               1.452
# 1   Mandarin Chinese(incl. Standard Chinese, but e...               1.118
# 2                                   Hindi(excl. Urdu)             602.200
# 3                                             Spanish             548.300
# 4                                              French             274.100
# 5              Modern Standard Arabic(excl. dialects)             274.000
# 6                                             Bengali             272.700
# 7                                             Russian             258.200
# 8                                          Portuguese             257.700
# 9                                   Urdu(excl. Hindi)             231.300
# 10                            Indonesian(excl. Malay)             199.000
# 11                                    Standard German             134.600
# ...

# %%
df_lang['Number of speakers'].dtypes
# Out:
# dtype('float64')

# %%
df_lang['Number of speakers'] = [
    1452000000,
    1118000000,
    602200000,
    548300000,
    274100000,
    274000000,
    272700000,
    258200000,
    257700000,
    231300000,
    199000000,
    134600000,
    125400000,
    120700000,
    99100000,
    95700000,
    88100000,
    86400000,
    85600000,
    85300000,
    82300000,
    81800000,
    81700000,
    77400000,
    77100000,
    74800000,
    71400000,
    68300000,
    67900000,
    66400000,
    64000000,
    62000000,
    60700000,
    57500000,
    52500000,
    51700000,
    49700000,
    47100000,
    45600000,
    44100000,
    43000000,
    42300000,
    40600000,
    40300000,
    40300000]

# %%
df_lang
# Out:
#                                              Language  Number of speakers  \
# 0                     English(excl. creole languages)          1452000000
# 1   Mandarin Chinese(incl. Standard Chinese, but e...          1118000000
# 2                                   Hindi(excl. Urdu)           602200000
# 3                                             Spanish           548300000
# 4                                              French           274100000
# 5              Modern Standard Arabic(excl. dialects)           274000000
# 6                                             Bengali           272700000
# 7                                             Russian           258200000
# 8                                          Portuguese           257700000
# 9                                   Urdu(excl. Hindi)           231300000
# 10                            Indonesian(excl. Malay)           199000000
# 11                                    Standard German           134600000
# ...

# %%
df_lang[df_lang['Countries'].str.contains('India')].sort_values(by = 'Number of speakers', ascending = False)
# Out:
#                                   Language  Number of speakers  \
# 2                        Hindi(excl. Urdu)           602200000
# 14                                 Marathi            99100000
# 15                                  Telugu            95700000
# 17                                   Tamil            86400000
# 29  Western Punjabi(excl. Eastern Punjabi)            66400000
# 30                                 Kannada            64000000
# 31                                Gujarati            62000000
# 34                                Bhojpuri            52500000
# 35  Eastern Punjabi(excl. Western Punjabi)            51700000
#
#    Degree of endangerment         Countries  GDP Per Capita  \
# 2                    Safe             India            2000
# 14                   Safe             India            2000
# 15                   Safe             India            2000
# 17                   Safe  India, Sri Lanka            3050
# ...

# %%
df_lang[df_lang['Language'].str.contains('Bengali')].sort_values(by = 'Number of speakers', ascending = False)
# Out:
#   Language  Number of speakers Degree of endangerment   Countries  \
# 6  Bengali           272700000                   Safe  Bangladesh
#
#    GDP Per Capita  Average number of years of schooling
# 6            1900                                   5.8

# %%
df_lang['Countries'][6] = 'Bangladesh, India'
# Out:
# <ipython-input-40-3f0725bf0c3d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang['Countries'][6] = 'Bangladesh, India'

# %%
df_lang[df_lang['Countries'].str.contains('India')].sort_values(by = 'Number of speakers', ascending = False)
# Out:
#                                   Language  Number of speakers  \
# 2                        Hindi(excl. Urdu)           602200000
# 6                                  Bengali           272700000
# 14                                 Marathi            99100000
# 15                                  Telugu            95700000
# 17                                   Tamil            86400000
# 29  Western Punjabi(excl. Eastern Punjabi)            66400000
# 30                                 Kannada            64000000
# 31                                Gujarati            62000000
# 34                                Bhojpuri            52500000
# 35  Eastern Punjabi(excl. Western Punjabi)            51700000
#
#    Degree of endangerment          Countries  GDP Per Capita  \
# 2                    Safe              India            2000
# 6                    Safe  Bangladesh, India            1900
# 14                   Safe              India            2000
# ...

# %%
sns.barplot(x = df_lang[df_lang['Countries'].str.contains('India')]['Language'],
            y = df_lang[df_lang['Countries'].str.contains('India')]['Number of speakers'],
            palette = 'spring')

plt.xlabel('Language')
plt.ylabel('Number of speakers')

plt.xticks(rotation = 45,
           horizontalalignment = 'right',
           fontweight = 'light',
           fontsize = 'large',
          )
plt.title('Indian languages')

plt.show()

# %%
df_lang['Language'][1] = 'Mandarin Chinese'
# Out:
# <ipython-input-59-e43326b6114a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang['Language'][1] = 'Mandarin Chinese'

# %%
df_lang[df_lang['Countries'].str.contains('China')].sort_values(by = 'Number of speakers', ascending = False)
# Out:
#                           Language  Number of speakers Degree of endangerment  \
# 1                 Mandarin Chinese          1118000000                   Safe
# 18    Yue Chinese(incl. Cantonese)            85600000                   Safe
# 21  Wu Chinese(incl. Shanghainese)            81800000                   Safe
# 36  Min Nan Chinese(incl. Hokkien)            49700000                   Safe
# 37                     Jin Chinese            47100000                   Safe
# 39                   Hakka Chinese            44100000                   Safe
#
#    Countries  GDP Per Capita  Avg. no. of years of schooling
# 1      China           10000                             7.8
# 18     China           10000                             7.8
# 21     China           10000                             7.8
# 36     China           10000                             7.8
# 37     China           10000                             7.8
# ...

# %%
sns.barplot(x = df_lang[df_lang['Countries'].str.contains('China')]['Language'],
            y = df_lang[df_lang['Countries'].str.contains('China')]['Number of speakers'],
            palette = 'winter')

plt.xlabel('Language')
plt.ylabel('Number of speakers')

plt.xticks(rotation = 45,
           horizontalalignment = 'right',
           fontweight = 'light',
           fontsize = 'medium',
          )
plt.title('Chinese languages')

plt.show()

# %%
df_lang.rename(columns={"Average number of years of schooling": "Avg. no. of years of schooling"}, inplace=True)

# %%
df_lang.corr()
# Out:
# <ipython-input-53-31eadbf30e90>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_lang.corr()
#                                 Number of speakers  GDP Per Capita  \
# Number of speakers                        1.000000        0.364154
# GDP Per Capita                            0.364154        1.000000
# Avg. no. of years of schooling            0.286799        0.805772
#
#                                 Avg. no. of years of schooling
# Number of speakers                                    0.286799
# GDP Per Capita                                        0.805772
# Avg. no. of years of schooling                        1.000000

# %%
plt.figure(figsize = (5,5))
sns.heatmap(data = df_lang.corr(),
            annot = True,
            cmap = 'cubehelix',
            vmin = 0,
            vmax = 1)
plt.show()
# Out:
# <ipython-input-57-45c6aed6ffd1>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data = df_lang.corr(),

# %%
df_lang
# Out:
#                                              Language  Number of speakers  \
# 0                     English(excl. creole languages)          1452000000
# 1   Mandarin Chinese(incl. Standard Chinese, but e...          1118000000
# 2                                   Hindi(excl. Urdu)           602200000
# 3                                             Spanish           548300000
# 4                                              French           274100000
# 5              Modern Standard Arabic(excl. dialects)           274000000
# 6                                             Bengali           272700000
# 7                                             Russian           258200000
# 8                                          Portuguese           257700000
# 9                                   Urdu(excl. Hindi)           231300000
# 10                            Indonesian(excl. Malay)           199000000
# 11                                    Standard German           134600000
# ...

# %%
df_lang.sort_values(by = 'GDP Per Capita', ascending = False)
# Out:
#                                              Language  Number of speakers  \
# 11                                    Standard German           134600000
# 0                     English(excl. creole languages)          1452000000
# 4                                              French           274100000
# 12                                           Japanese           125400000
# 28                                            Italian            67900000
# 22                                             Korean            81700000
# 3                                             Spanish           548300000
# 5              Modern Standard Arabic(excl. dialects)           274000000
# 8                                          Portuguese           257700000
# 42                                             Polish            40600000
# 7                                             Russian           258200000
# 21                     Wu Chinese(incl. Shanghainese)            81800000
# ...

# %%
df_lang.sort_values(by = 'Average number of years of schooling', ascending = False)
# Out:
#                                              Language  Number of speakers  \
# 11                                    Standard German           134600000
# 0                     English(excl. creole languages)          1452000000
# 12                                           Japanese           125400000
# 22                                             Korean            81700000
# 7                                             Russian           258200000
# 42                                             Polish            40600000
# 4                                              French           274100000
# 28                                            Italian            67900000
# 25  Egyptian Spoken Arabic(excl. other Arabic dial...            74800000
# 3                                             Spanish           548300000
# 23              Iranian Persian(excl. Dari and Tajik)            77400000
# 20                                         Tagalog[b]            82300000
# ...

# %%
# In Tableau - can make a line plot showcasing the correlating trend between GDP Per Capita and the Average number of years of schooling
# Can also make a further line plot of the number of speakers, to show to lack of correlation with the further two features.

# %%
df_lang.to_csv('langsafe.csv')
