# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Endanger_data = "Endangered_languages.zip"
df_end = pd.read_csv(Endanger_data)

# %%
df_end.head(20)
# Out:
#       ID              Name in English                    Name in French  \
# 0   1022                South Italian                    italien du sud
# 1   1023                     Sicilian                          sicilien
# 2    383                    Low Saxon                         bas-saxon
# 3    335                   Belarusian                        biélorusse
# 4    382                      Lombard                           lombard
# 5    405                       Romani                            romani
# 6   2211             Yiddish (Israel)                  yiddish (Israël)
# 7   1586                        Gondi                             gondi
# 8   1020         Limburgian-Ripuarian  francique ripuaire -limbourgeois
# 9   1943  Quechua of Southern Bolivia           quechua bolivien du sud
# 10  1565                      Kumaoni                           kumaoni
# 11   755                       Aymara                            aymara
# ...

# %%
df_end.shape
# Out:
# (2722, 15)

# %%
df = df_end.drop(columns = ['Name in French', 'Name in Spanish', 'Country codes alpha 3', 'ISO639-3 codes', 'Alternate names',	'Name in the language', 'Sources', 'Latitude', 'Longitude', 'Description of the location'], axis = 1, inplace = True)

# %%
df

# %%
df_end
# Out:
#         ID    Name in English  \
# 0     1022      South Italian
# 1     1023           Sicilian
# 2      383          Low Saxon
# 3      335         Belarusian
# 4      382            Lombard
# ...    ...                ...
# 2717  1972           Yonaguni
# 2718  2018             Yucuna
# 2719  2015  Yurutí (Colombia)
# 2720  2716          Zangskari
# 2721  2177            Zidgali
#
#                                               Countries  \
# 0                                                 Italy
# 1                                                 Italy
# 2     Germany, Denmark, Netherlands, Poland, Russian...
# 3     Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                    Italy, Switzerland
# ...                                                 ...
# 2717                                              Japan
# 2718                                           Colombia
# 2719                                           Colombia
# ...

# %%
df_end.isnull().sum()
# Out:
# ID                          0
# Name in English             0
# Countries                   1
# Degree of endangerment      0
# Number of speakers        183
# dtype: int64

# %%
df_end['GDP Per Capita'] = '*GDP Per Capita*'

# %%
df_end['Most likely cause of death'] = '*Most likely cause of death*'

# %%
df_end
# Out:
#         ID    Name in English  \
# 0     1022      South Italian
# 1     1023           Sicilian
# 2      383          Low Saxon
# 3      335         Belarusian
# 4      382            Lombard
# ...    ...                ...
# 2717  1972           Yonaguni
# 2718  2018             Yucuna
# 2719  2015  Yurutí (Colombia)
# 2720  2716          Zangskari
# 2721  2177            Zidgali
#
#                                               Countries  \
# 0                                                 Italy
# 1                                                 Italy
# 2     Germany, Denmark, Netherlands, Poland, Russian...
# 3     Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                    Italy, Switzerland
# ...                                                 ...
# 2717                                              Japan
# 2718                                           Colombia
# 2719                                           Colombia
# ...

# %%
df_end.drop(columns = ['ID'], axis =1, inplace = True)

# %%
df_end
# Out:
#         Name in English                                          Countries  \
# 0         South Italian                                              Italy
# 1              Sicilian                                              Italy
# 2             Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3            Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4               Lombard                                 Italy, Switzerland
# ...                 ...                                                ...
# 2717           Yonaguni                                              Japan
# 2718             Yucuna                                           Colombia
# 2719  Yurutí (Colombia)                                           Colombia
# 2720          Zangskari                                    India, Pakistan
# 2721            Zidgali                                               Oman
#
#      Degree of endangerment  Number of speakers    GDP Per Capita  \
# ...

# %%
df_end.rename(columns={"Name in English": "Language"}, inplace=True)

# %%
df_end
# Out:
#                Language                                          Countries  \
# 0         South Italian                                              Italy
# 1              Sicilian                                              Italy
# 2             Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3            Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4               Lombard                                 Italy, Switzerland
# ...                 ...                                                ...
# 2717           Yonaguni                                              Japan
# 2718             Yucuna                                           Colombia
# 2719  Yurutí (Colombia)                                           Colombia
# 2720          Zangskari                                    India, Pakistan
# 2721            Zidgali                                               Oman
#
#      Degree of endangerment  Number of speakers    GDP Per Capita  \
# ...

# %%
df_end[['Language', 'Number of speakers', 'Degree of endangerment', 'Countries', 'GDP Per Capita',	'Most likely cause of death']]
# Out:
#                Language  Number of speakers Degree of endangerment  \
# 0         South Italian           7500000.0             Vulnerable
# 1              Sicilian           5000000.0             Vulnerable
# 2             Low Saxon           4800000.0             Vulnerable
# 3            Belarusian           4000000.0             Vulnerable
# 4               Lombard           3500000.0  Definitely endangered
# ...                 ...                 ...                    ...
# 2717           Yonaguni                 NaN    Severely endangered
# 2718             Yucuna                 NaN  Definitely endangered
# 2719  Yurutí (Colombia)                 NaN  Definitely endangered
# 2720          Zangskari                 NaN  Definitely endangered
# 2721            Zidgali                 NaN  Critically endangered
#
#                                               Countries    GDP Per Capita  \
# 0                                                 Italy  *GDP Per Capita*
# ...

# %%
df_end
# Out:
#                Language                                          Countries  \
# 0         South Italian                                              Italy
# 1              Sicilian                                              Italy
# 2             Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3            Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4               Lombard                                 Italy, Switzerland
# ...                 ...                                                ...
# 2717           Yonaguni                                              Japan
# 2718             Yucuna                                           Colombia
# 2719  Yurutí (Colombia)                                           Colombia
# 2720          Zangskari                                    India, Pakistan
# 2721            Zidgali                                               Oman
#
#      Degree of endangerment  Number of speakers    GDP Per Capita  \
# ...

# %%
df_end.isnull().sum()
# Out:
# Language                        0
# Countries                       1
# Degree of endangerment          0
# Number of speakers            183
# GDP Per Capita                  0
# Most likely cause of death      0
# dtype: int64

# %%
def null_vals(dataframe):
    '''function to show both number of nulls and the percentage of nulls in the whole column'''
    null_vals = dataframe.isnull().sum() ## How many nulls in each column
    total_cnt = len(dataframe) ## Total entries in the dataframe
    null_vals = pd.DataFrame(null_vals,columns=['null']) ## Put the number of nulls in a single dataframe
    null_vals['percent'] = round((null_vals['null']/total_cnt)*100,3) ## Round how many nulls are there, as %, of the df

    return null_vals.sort_values('percent', ascending=False)

# %%
null_vals(df_end)
# Out:
#                             null  percent
# Number of speakers           183    6.723
# Countries                      1    0.037
# Language                       0    0.000
# Degree of endangerment         0    0.000
# GDP Per Capita                 0    0.000
# Most likely cause of death     0    0.000

# %%
df_end.dropna(
    axis = 0, # default
    how = 'any', # default
    subset = ['Number of speakers', 'Countries'],   # subset tells dropna which columns to consider
    inplace = True # makes change permanent
)

# %%
null_vals(df_end)
# Out:
#                             null  percent
# Language                       0      0.0
# Countries                      0      0.0
# Degree of endangerment         0      0.0
# Number of speakers             0      0.0
# GDP Per Capita                 0      0.0
# Most likely cause of death     0      0.0

# %%
df_end
# Out:
#            Language                                          Countries  \
# 0     South Italian                                              Italy
# 1          Sicilian                                              Italy
# 2         Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3        Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4           Lombard                                 Italy, Switzerland
# ...             ...                                                ...
# 2534         |'Auni                                       South Africa
# 2535           |Xam                                       South Africa
# 2536        ǁKu ǁ'e                                       South Africa
# 2537         ǁKx'au                                       South Africa
# 2538         ǁXegwi                                       South Africa
#
#      Degree of endangerment  Number of speakers    GDP Per Capita  \
# ...

# %%
df_end.describe()
# Out:
#        Number of speakers
# count        2.538000e+03
# mean         5.367221e+04
# std          3.115227e+05
# min          0.000000e+00
# 25%          5.000000e+01
# 50%          8.000000e+02
# 75%          6.865000e+03
# max          7.500000e+06

# %%
df_end.drop(columns = ['Most likely cause of death'], inplace = True)

# %%
df_end
# Out:
#            Language                                          Countries  \
# 0     South Italian                                              Italy
# 1          Sicilian                                              Italy
# 2         Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3        Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4           Lombard                                 Italy, Switzerland
# ...             ...                                                ...
# 2534         |'Auni                                       South Africa
# 2535           |Xam                                       South Africa
# 2536        ǁKu ǁ'e                                       South Africa
# 2537         ǁKx'au                                       South Africa
# 2538         ǁXegwi                                       South Africa
#
#      Degree of endangerment  Number of speakers    GDP Per Capita
# ...

# %%
df_end.drop(columns = ['GDP Per Capita'], inplace = True)

# %%
df_end
# Out:
#            Language                                          Countries  \
# 0     South Italian                                              Italy
# 1          Sicilian                                              Italy
# 2         Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3        Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4           Lombard                                 Italy, Switzerland
# ...             ...                                                ...
# 2534         |'Auni                                       South Africa
# 2535           |Xam                                       South Africa
# 2536        ǁKu ǁ'e                                       South Africa
# 2537         ǁKx'au                                       South Africa
# 2538         ǁXegwi                                       South Africa
#
#      Degree of endangerment  Number of speakers
# 0                Vulnerable           7500000.0
# ...

# %%
df

# %%
mapping = {'Vulnerable':1, 'Definitely endangered':2, 'Severely endangered':3, 'Critically endangered':4, 'Extinct':5}

df_end['Danger scale'] = df_end['Degree of endangerment'].map(mapping)

# %%
df_end.dtypes
# Out:
# Language                   object
# Countries                  object
# Degree of endangerment     object
# Number of speakers        float64
# Danger scale                int64
# dtype: object

# %%
df_end.isnull().sum()
# Out:
# Language                  0
# Countries                 0
# Degree of endangerment    0
# Number of speakers        0
# Danger scale              0
# dtype: int64

# %%
df_end
# Out:
#            Language                                          Countries  \
# 0     South Italian                                              Italy
# 1          Sicilian                                              Italy
# 2         Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3        Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4           Lombard                                 Italy, Switzerland
# ...             ...                                                ...
# 2534         |'Auni                                       South Africa
# 2535           |Xam                                       South Africa
# 2536        ǁKu ǁ'e                                       South Africa
# 2537         ǁKx'au                                       South Africa
# 2538         ǁXegwi                                       South Africa
#
#      Degree of endangerment  Number of speakers  Danger scale
# ...

# %%
df_end.corr()
# Out:
# <ipython-input-35-058594cee658>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_end.corr()
#                     Number of speakers  Danger scale
# Number of speakers            1.000000     -0.171146
# Danger scale                 -0.171146      1.000000

# %%
plt.figure(figsize = (5,5))
sns.heatmap(data = df_end.corr(),
            annot = True,
            cmap = 'tab10',
            vmin = 0,
            vmax = 1)
plt.show()
# Out:
# <ipython-input-97-85c3ad529b74>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data = df_end.corr(),

# %%
df_end.groupby('Degree of endangerment')[['Language']].count()
# Out:
#                         Language
# Degree of endangerment
# Critically endangered        544
# Definitely endangered        634
# Extinct                      244
# Severely endangered          505
# Vulnerable                   611

# %%
sns.displot(df_end.groupby('Degree of endangerment')[['Language']].count())

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_end.groupby('Degree of endangerment')[['Degree of endangerment', 'Number of speakers']].mean().sort_values(by = 'Number of speakers', ascending = False)
# Out:
# <ipython-input-39-b71c939b2735>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_end.groupby('Degree of endangerment')[['Degree of endangerment', 'Number of speakers']].mean().sort_values(by = 'Number of speakers', ascending = False)
#                         Number of speakers
# Degree of endangerment
# Vulnerable                   148928.222586
# Definitely endangered         62276.686120
# Severely endangered           10349.477228
# Critically endangered           921.669118
# Extinct                          55.909836

# %%
sns.countplot(x = 'Degree of endangerment',
              data = df_end,
              palette = 'colorblind')

plt.xlabel('Degree of endangerment')
plt.ylabel('language count')

plt.xticks(rotation = 45,
           horizontalalignment = 'right',
           fontweight = 'light',
           fontsize = 'small',
          )
plt.title('Degree of endangerment')

plt.show()

# %%
df_end[df_end['Countries'].str.contains('Italy')].sort_values(by = 'Number of speakers', ascending = False)
# Out:
#                Language                                          Countries  \
# 0         South Italian                                              Italy
# 1              Sicilian                                              Italy
# 4               Lombard                                 Italy, Switzerland
# 5                Romani  Albania, Germany, Austria, Belarus, Bosnia and...
# 12     Emilian-Romagnol                                  Italy, San Marino
# 13          Piedmontese                                              Italy
# 14              Venetan                           Croatia, Italy, Slovenia
# 30             Ligurian                              France, Italy, Monaco
# 36          Campidanese                                              Italy
# 53             Friulian                                              Italy
# 80           Logudorese                                              Italy
# ...

# %%
sns.countplot(x = 'Degree of endangerment',
              data = df_end[df_end['Countries'].str.contains('Italy')],
              palette = 'winter')

plt.xlabel('Degree of endangerment')
plt.ylabel('Italian language count')

plt.xticks(rotation = 45,
           horizontalalignment = 'right',
           fontweight = 'light',
           fontsize = 'large',
          )
plt.title('Italian languages')

plt.show()

# %%
df_end[df_end['Countries'].str.contains('India')].sort_values(by = 'Number of speakers', ascending = False)
# Out:
#            Language     Countries Degree of endangerment  Number of speakers  \
# 7             Gondi         India             Vulnerable           2713790.0
# 10          Kumaoni  India, Nepal             Vulnerable           2003783.0
# 16    Kurux (India)         India             Vulnerable           1751489.0
# 18             Tulu         India             Vulnerable           1722768.0
# 19           Kangdi         India  Definitely endangered           1700000.0
# ...             ...           ...                    ...                 ...
# 2284           Ahom         India                Extinct                 0.0
# 2291          Andro         India                Extinct                 0.0
# 2323        Chairel         India                Extinct                 0.0
# 2477        Rangkas         India                Extinct                 0.0
# 2481        Sengmai         India                Extinct                 0.0
#
#       Danger scale
# 7                1
# ...

# %%
sns.countplot(x = 'Degree of endangerment',
              data = df_end[df_end['Countries'].str.contains('India')],
              palette = 'winter')

plt.xlabel('Degree of endangerment')
plt.ylabel('Indian language count')

plt.xticks(rotation = 45,
           horizontalalignment = 'right',
           fontweight = 'light',
           fontsize = 'small',
          )
plt.title('Indian languages')

plt.show()

# %%
df_end[df_end['Countries'].str.contains('Pakistan')].sort_values(by = 'Number of speakers', ascending = False)
# Out:
#           Language                                          Countries  \
# 61          Brahui  Iran (Islamic Republic of), Pakistan, Afghanistan
# 114         Khowar                                           Pakistan
# 115          Maiya                                           Pakistan
# 189     Burushaski                                           Pakistan
# 205          Wakhi           China, Pakistan, Tajikistan, Afghanistan
# 210     Bhadravahi                                    India, Pakistan
# 224        Torwali                                           Pakistan
# 339         Bateri                                           Pakistan
# 410           Kati                              Pakistan, Afghanistan
# 556     Gawar-Bati                              Pakistan, Afghanistan
# 573        Phalura                                           Pakistan
# 690         Yidgha                                           Pakistan
# ...

# %%
sns.countplot(x = 'Degree of endangerment',
              data = df_end[df_end['Countries'].str.contains('Pakistan')],
              palette = 'winter')

plt.xlabel('Degree of endangerment')
plt.ylabel('Pakistani language count')

plt.xticks(rotation = 45,
           horizontalalignment = 'right',
           fontweight = 'light',
           fontsize = 'large',
          )
plt.title('Pakistani languages')

plt.show()

# %%
df_end[df_end['Countries'].str.contains('South Africa')].sort_values(by = 'Number of speakers', ascending = False)
# Out:
#            Language     Countries Degree of endangerment  Number of speakers  \
# 1821           Xiri  South Africa  Critically endangered                87.0
# 2151           N|uu  South Africa  Critically endangered                 8.0
# 2161         Korana  South Africa  Critically endangered                 6.0
# 2282        !Gan!ne  South Africa                Extinct                 0.0
# 2317  Cape Khoekhoe  South Africa                Extinct                 0.0
# 2534         |'Auni  South Africa                Extinct                 0.0
# 2535           |Xam  South Africa                Extinct                 0.0
# 2536        ǁKu ǁ'e  South Africa                Extinct                 0.0
# 2537         ǁKx'au  South Africa                Extinct                 0.0
# 2538         ǁXegwi  South Africa                Extinct                 0.0
#
#       Danger scale
# 1821             4
# 2151             4
# 2161             4
# 2282             5
# 2317             5
# ...

# %%
df_end[df_end['Countries'].str.contains('South Africa')].sort_values(by = 'Number of speakers', ascending = False).shape
# Out:
# (10, 5)

# %%
sns.countplot(x = 'Degree of endangerment',
              data = df_end[df_end['Countries'].str.contains('South Africa')],
              palette = 'winter')

plt.xlabel('Degree of endangerment')
plt.ylabel('SA language count')

plt.xticks(rotation = 45,
           horizontalalignment = 'right',
           fontweight = 'light',
           fontsize = 'large',
          )
plt.title('SA languages')

plt.show()

# %%
df_end[df_end['Countries'].str.contains('Russian Federation')].sort_values(by = 'Number of speakers', ascending = False)
# Out:
#              Language                                          Countries  \
# 2           Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3          Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 5              Romani  Albania, Germany, Austria, Belarus, Bosnia and...
# 23            Bashkir                                 Russian Federation
# 24            Chechen                                 Russian Federation
# ...               ...                                                ...
# 2298             Arin                                 Russian Federation
# 2287     Akkala Saami                                 Russian Federation
# 2286  Ainu (Sakhalin)                                 Russian Federation
# 2285     Ainu (Kuril)                                 Russian Federation
# 2531           Yurats                                 Russian Federation
#
#      Degree of endangerment  Number of speakers  Danger scale
# ...

# %%
sns.countplot(x = 'Degree of endangerment',
              data = df_end[df_end['Countries'].str.contains('Russian Federation')],
              palette = 'colorblind')

plt.xlabel('Degree of endangerment')
plt.ylabel('Russian language count')

plt.xticks(rotation = 45,
           horizontalalignment = 'right',
           fontweight = 'light',
           fontsize = 'small',
          )
plt.title('Russian languages')

plt.show()

# %%
df_end[df_end['Countries'].str.contains('Brazil')].sort_values(by = 'Number of speakers', ascending = False)
# Out:
#               Language               Countries Degree of endangerment  \
# 298             Ticuna  Brazil, Colombia, Peru  Definitely endangered
# 392     Kaiowá Guarani                  Brazil             Vulnerable
# 409             Terena                  Brazil    Severely endangered
# 412           Kaingang                  Brazil  Definitely endangered
# 439   Macushi (Brazil)                  Brazil             Vulnerable
# ...                ...                     ...                    ...
# 2418              Máku                  Brazil                Extinct
# 2365  Huitoto (Brazil)                  Brazil                Extinct
# 2296           Arapáso                  Brazil                Extinct
# 2289           Amanayé                  Brazil                Extinct
# 2532   Yurutí (Brazil)                  Brazil                Extinct
#
#       Number of speakers  Danger scale
# 298              35000.0             2
# 392              20000.0             1
# ...

# %%
sns.countplot(x = 'Degree of endangerment',
              data = df_end[df_end['Countries'].str.contains('Brazil')],
              palette = 'spring')

plt.xlabel('Degree of endangerment')
plt.ylabel('Brazilian language count')

plt.xticks(rotation = 45,
           horizontalalignment = 'right',
           fontweight = 'light',
           fontsize = 'small',
          )
plt.title('Brazilian languages')

plt.show()

# %%
df_end[df_end['Countries'].str.contains('United Kingdom')].sort_values(by = 'Number of speakers', ascending = False)
# Out:
#              Language                                          Countries  \
# 5              Romani  Albania, Germany, Austria, Belarus, Bosnia and...
# 20              Scots  United Kingdom of Great Britain and Northern I...
# 45              Welsh  United Kingdom of Great Britain and Northern I...
# 227   Scottish Gaelic  United Kingdom of Great Britain and Northern I...
# 260             Irish  Ireland, United Kingdom of Great Britain and N...
# 877     Jersey French  United Kingdom of Great Britain and Northern I...
# 1092  Guernsey French  United Kingdom of Great Britain and Northern I...
# 2288  Alderney French  United Kingdom of Great Britain and Northern I...
# 2449             Norn  United Kingdom of Great Britain and Northern I...
#
#      Degree of endangerment  Number of speakers  Danger scale
# 5     Definitely endangered           3500000.0             2
# 20               Vulnerable           1500000.0             1
# ...

# %%
sns.countplot(x = 'Degree of endangerment',
              data = df_end[df_end['Countries'].str.contains('United Kingdom')],
              palette = 'winter')

plt.xlabel('Degree of endangerment')
plt.ylabel('British language count')

plt.xticks(rotation = 45,
           horizontalalignment = 'right',
           fontweight = 'light',
           fontsize = 'large',
          )
plt.title('British languages')

plt.show()

# %%
df_end[df_end['Countries'].str.contains('United States of America')].sort_values(by = 'Number of speakers', ascending = False)
# Out:
#                        Language                 Countries  \
# 156                      Navajo  United States of America
# 359                       Sioux  United States of America
# 443            O'odham (Akimel)  United States of America
# 444            O'odham (Tohono)  United States of America
# 502   Central Alaskan Yupik (2)  United States of America
# ...                         ...                       ...
# 2377                      Kansa  United States of America
# 2382                       Kato  United States of America
# 2393              Klamath-Modoc  United States of America
# 2394                   Konomihu  United States of America
# 2530                       Yuki  United States of America
#
#      Degree of endangerment  Number of speakers  Danger scale
# 156              Vulnerable            120000.0             1
# 359              Vulnerable             25000.0             1
# 443   Definitely endangered             15000.0             2
# ...

# %%
sns.countplot(x = 'Degree of endangerment',
              data = df_end[df_end['Countries'].str.contains('United States of America')],
              palette = 'cubehelix')

plt.xlabel('Degree of endangerment')
plt.ylabel('American language count')

plt.xticks(rotation = 45,
           horizontalalignment = 'right',
           fontweight = 'light',
           fontsize = 'small',
          )
plt.title('American languages')

plt.show()

# %%
df_end[df_end['Countries'].str.contains('Canada')].sort_values(by = 'Number of speakers', ascending = False)
# Out:
#              Language Countries Degree of endangerment  Number of speakers  \
# 381       Plains Cree    Canada             Vulnerable             20933.0
# 419       Swampy Cree    Canada             Vulnerable             16685.0
# 560   Nunavimmiutitut    Canada             Vulnerable              9105.0
# 561        Woods Cree    Canada             Vulnerable              9095.0
# 579              Dene    Canada             Vulnerable              8195.0
# ...               ...       ...                    ...                 ...
# 1968   Comox/Sliammon    Canada  Critically endangered                30.0
# 2058          Sechelt    Canada  Critically endangered                15.0
# 2111  Munsee (Canada)    Canada  Critically endangered                10.0
# 2466        Pentlatch    Canada                Extinct                 0.0
# 2505         Tsetsaut    Canada                Extinct                 0.0
#
#       Danger scale
# 381              1
# 419              1
# ...

# %%
sns.countplot(x = 'Degree of endangerment',
              data = df_end[df_end['Countries'].str.contains('Canada')],
              palette = 'winter')

plt.xlabel('Degree of endangerment')
plt.ylabel('Canadian language count')

plt.xticks(rotation = 45,
           horizontalalignment = 'right',
           fontweight = 'light',
           fontsize = 'large',
          )
plt.title('Canadian languages')

plt.show()

# %%
df_end[df_end['Countries'].str.contains('Australia')].sort_values(by = 'Number of speakers', ascending = False)
# Out:
#             Language  Countries Degree of endangerment  Number of speakers  \
# 863   Pitjantjatjara  Australia             Vulnerable              3000.0
# 873         Warlpiri  Australia             Vulnerable              3000.0
# 906      Martuwangka  Australia             Vulnerable              2500.0
# 940             Tiwi  Australia             Vulnerable              2100.0
# 944     Anindilyakwa  Australia             Vulnerable              2000.0
# ...              ...        ...                    ...                 ...
# 2400         Kurtjar  Australia                Extinct                 0.0
# 2422          Marrgu  Australia                Extinct                 0.0
# 2444          Ngarla  Australia                Extinct                 0.0
# 2519      Wangkumara  Australia  Critically endangered                 0.0
# 2526      Yir Yoront  Australia                Extinct                 0.0
#
#       Danger scale
# 863              1
# 873              1
# ...

# %%
sns.countplot(x = 'Degree of endangerment',
              data = df_end[df_end['Countries'].str.contains('Australia')],
              palette = 'winter')

plt.xlabel('Degree of endangerment')
plt.ylabel('Australian language count')

plt.xticks(rotation = 45,
           horizontalalignment = 'right',
           fontweight = 'light',
           fontsize = 'large',
          )
plt.title('Australian languages')

plt.show()

# %%
df_end[df_end['Countries'].str.contains('New Zealand')].sort_values(by = 'Number of speakers', ascending = False)
# Out:
#     Language    Countries Degree of endangerment  Number of speakers  \
# 208    Maori  New Zealand             Vulnerable             70000.0
#
#      Danger scale
# 208             1

# %%
df_end
# Out:
#            Language                                          Countries  \
# 0     South Italian                                              Italy
# 1          Sicilian                                              Italy
# 2         Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3        Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4           Lombard                                 Italy, Switzerland
# ...             ...                                                ...
# 2534         |'Auni                                       South Africa
# 2535           |Xam                                       South Africa
# 2536        ǁKu ǁ'e                                       South Africa
# 2537         ǁKx'au                                       South Africa
# 2538         ǁXegwi                                       South Africa
#
#      Degree of endangerment  Number of speakers  Danger scale
# ...

# %%
sns.barplot(x = df_end[df_end['Countries'].str.contains('India')]['Language'],
            y = df_end[df_end['Countries'].str.contains('India')]['Number of speakers'],
            palette = 'summer')

plt.xlabel('Language')
plt.ylabel('Number of speakers')

plt.xticks(rotation = 45,
           horizontalalignment = 'right',
           fontweight = 'light',
           fontsize = 'medium',
          )
plt.title('Indian languages')

plt.show()

# %%
English_df = df_end[(df_end['Countries'] == 'United Kingdom of Great Britain and Northern Ireland') | (df_end['Countries'] == 'United States of America') | (df_end['Countries'] == 'Canada') | (df_end['Countries'] == 'Australia') | (df_end['Countries'] == 'New Zealand')]

# %%
English_df
# Out:
#              Language                                          Countries  \
# 20              Scots  United Kingdom of Great Britain and Northern I...
# 45              Welsh  United Kingdom of Great Britain and Northern I...
# 156            Navajo                           United States of America
# 208             Maori                                        New Zealand
# 227   Scottish Gaelic  United Kingdom of Great Britain and Northern I...
# ...               ...                                                ...
# 2519       Wangkumara                                          Australia
# 2520            Wappo                           United States of America
# 2522            Wiyot                           United States of America
# 2526       Yir Yoront                                          Australia
# 2530             Yuki                           United States of America
#
#      Degree of endangerment  Number of speakers  Danger scale
# ...

# %%
English_df.groupby('Countries')[['Countries', 'Number of speakers', 'Danger scale']].mean().sort_values(by = 'Number of speakers', ascending = False)
# Out:
# <ipython-input-106-649ad34a6834>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   English_df.groupby('Countries')[['Countries', 'Number of speakers', 'Danger scale']].mean().sort_values(by = 'Number of speakers', ascending = False)
#                                                     Number of speakers  \
# Countries
# United Kingdom of Great Britain and Northern Ir...       330393.285714
# New Zealand                                               70000.000000
# Canada                                                     2326.126984
# United States of America                                   1659.067633
# Australia                                                   238.700935
#
#                                                     Danger scale
# Countries
# ...

# %%
sns.countplot(x = 'Countries',
              data = English_df,
              palette = 'colorblind')

plt.xlabel('Country')
plt.ylabel('Count')

plt.xticks(rotation = 45,
           horizontalalignment = 'right',
           fontweight = 'light',
           fontsize = 'small',
          )
plt.title('English speaking countries')

plt.show()

# %%
sns.countplot(x = 'Degree of endangerment',
              data = English_df,
              palette = 'summer')

plt.xlabel('Status')
plt.ylabel('Count')

plt.xticks(rotation = 45,
           horizontalalignment = 'right',
           fontweight = 'light',
           fontsize = 'small',
          )
plt.title('English speaking countries')

plt.show()

# %%
sns.countplot(x = 'Danger scale',
              data = English_df,
              palette = 'summer')

plt.xlabel('Danger scale')
plt.ylabel('Count')

plt.xticks(rotation = 45,
           horizontalalignment = 'left',
           fontweight = 'light',
           fontsize = 'small',
          )
plt.title('English speaking countries')

plt.show()

# %%
sns.barplot(x = English_df['Countries'],
            y = English_df['Number of speakers'],
            palette = 'summer')

plt.xlabel('Countries')
plt.ylabel('Number of speakers')

plt.xticks(rotation = 45,
           horizontalalignment = 'right',
           fontweight = 'light',
           fontsize = 'medium',
          )
plt.title('English speaking countries')

plt.show()

# %%
sns.displot(
            x = 'Countries',
            data = English_df,
            bins = 5
           )

plt.xticks(rotation = 45,
           horizontalalignment = 'right',
           fontweight = 'light',
           fontsize = 'small',
          )

plt.show()

# %%
def speaker_number_ranges(x):
    if x<500000:
        return '0-0.5 Mil.'
    elif x<1000000:
        return '0.5-1 Mil.'
    elif x<2000000:
        return '1-2 Mil.'
    elif x<4000000:
        return '2-4 Mil.'
    elif x<6000000:
        return '4-6 Mil.'
    elif x<7500000:
        return '6-7.5 Mil.'
    else:
        return '7.5+ Mil.'

df_end['Number of speakers range'] = df_end['Number of speakers'].apply(speaker_number_ranges)

# %%
df_end
# Out:
#            Language                                          Countries  \
# 0     South Italian                                              Italy
# 1          Sicilian                                              Italy
# 2         Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3        Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4           Lombard                                 Italy, Switzerland
# ...             ...                                                ...
# 2534         |'Auni                                       South Africa
# 2535           |Xam                                       South Africa
# 2536        ǁKu ǁ'e                                       South Africa
# 2537         ǁKx'au                                       South Africa
# 2538         ǁXegwi                                       South Africa
#
#      Degree of endangerment  Number of speakers  Danger scale  \
# ...

# %%
df_end[['Number of speakers range']].value_counts()
# Out:
# Number of speakers range
# 0-0.5 Mil.                  2474
# 0.5-1 Mil.                    31
# 1-2 Mil.                      17
# 2-4 Mil.                      12
# 4-6 Mil.                       3
# 7.5+ Mil.                      1
# dtype: int64

# %%
plt.figure(figsize = (16,9))

sns.countplot(data = df_end,
              x = 'Number of speakers range',
              palette = 'viridis',
              order = ['0-0.5 Mil.','0.5-1 Mil.','1-2 Mil.','2-4 Mil.','4-6 Mil.','6-7.5 Mil.','7.5+ Mil.'])

plt.show()

# %%
df_end[df_end['Number of speakers range'] == '0-0.5 Mil.']
# Out:
#               Language           Countries Degree of endangerment  \
# 64             Mahasui               India  Definitely endangered
# 65               Magar               Nepal  Definitely endangered
# 66     Mam (Guatemala)           Guatemala             Vulnerable
# 67              Udmurt  Russian Federation  Definitely endangered
# 68    Huasteca Náhuatl              Mexico             Vulnerable
# ...                ...                 ...                    ...
# 2534            |'Auni        South Africa                Extinct
# 2535              |Xam        South Africa                Extinct
# 2536           ǁKu ǁ'e        South Africa                Extinct
# 2537            ǁKx'au        South Africa                Extinct
# 2538            ǁXegwi        South Africa                Extinct
#
#       Number of speakers  Danger scale Number of speakers range
# 64              496024.0             2               0-0.5 Mil.
# ...

# %%
df_end[df_end['Number of speakers range'] == '0-0.5 Mil.'].groupby('Countries')[['Countries', 'Number of speakers', 'Danger scale']].mean().sort_values(by = 'Number of speakers', ascending = False)
# Out:
# <ipython-input-78-091f56871af8>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_end[df_end['Number of speakers range'] == '0-0.5 Mil.'].groupby('Countries')[['Countries', 'Number of speakers', 'Danger scale']].mean().sort_values(by = 'Number of speakers', ascending = False)
#                                                     Number of speakers  \
# Countries
# Germany, Belgium, France, Luxembourg                          390000.0
# Netherlands                                                   350000.0
# Iraq, Israel, Jordan, The former Yugoslav Repub...            300000.0
# Armenia, Georgia, Greece, Russian Federation, T...            300000.0
# China, Kyrgyzstan, Mongolia                                   280000.0
# ...

# %%
CE = df_end[df_end['Degree of endangerment'] == 'Critically endangered']

# %%
CE
# Out:
#               Language                           Countries  \
# 232              Parji                               India
# 250           Zenatiya                             Algeria
# 307               Mayo                              Mexico
# 310           Sirmaudi                               India
# 332           Tidikelt                             Algeria
# ...                ...                                 ...
# 2429     Mirití Tapuia                              Brazil
# 2458   Omagua (Brazil)                              Brazil
# 2478  Sanhaja of Srair                             Morocco
# 2518             Wanai  Venezuela (Bolivarian Republic of)
# 2519        Wangkumara                           Australia
#
#      Degree of endangerment  Number of speakers  Danger scale  \
# 232   Critically endangered             51216.0             4
# 250   Critically endangered             50000.0             4
# 307   Critically endangered             32869.0             4
# ...

# %%
CE[['Countries']].value_counts().head(15)
# Out:
# Countries
# United States of America    78
# Brazil                      43
# Australia                   41
# India                       37
# Indonesia                   30
# China                       22
# Vanuatu                     22
# Mexico                      21
# Papua New Guinea            20
# Russian Federation          19
# Canada                      14
# Peru                        14
# Cameroon                    14
# Sudan                       13
# Nigeria                     12
# dtype: int64

# %%
sns.barplot(x = CE['Countries'],
            y = CE[['Countries']].value_counts().head(15),
            palette = 'autumn')

plt.xlabel('Countries')
plt.ylabel('Number of languages')

plt.xticks(rotation = 45,
           horizontalalignment = 'right',
           fontweight = 'light',
           fontsize = 'medium',
          )
plt.title('Critically Endangered Languages')

plt.show()
